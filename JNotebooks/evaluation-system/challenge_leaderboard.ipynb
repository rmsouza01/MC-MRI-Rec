# %%
# %matplotlib inline
import numpy as np
import os
import glob
import pickle
import h5py
from metrics import metrics

results = glob.glob("/media/roberto/ROBERTO-5TB/GDrive/PDF-Calgary/Applications/MIDL-2020-challenge/Results-submissions/Metrics/*.pickle")
crop = 30,30
nslices = 256
nfiles = 50

print("Track 01 - 12-channel")
print("R = 5")
t1_r5 = 'track01_12_channel_R=5'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t1_r5 in res:
        res = res[t1_r5]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))

print("\n\n")

print("R = 10")
t1_r10 = 'track01_12_channel_R=10'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t1_r10 in res:
        res = res[t1_r10]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))
# Out:
# Track 01 - 12-channel
# R = 5
# team01,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
# team02,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
# zero-filled-baseline,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
#
#
#
# R = 10
# team01,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273
# team02,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273
# zero-filled-baseline,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273

# %%
print("Track 02 - 12-channel")
print("R = 5")
t2_c12_r5 = 'track02_12_channel_R=5'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t2_c12_r5 in res:
        res = res[t2_c12_r5]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))

print("\n\n")

print("R = 10")
t2_c12_r10 = 'track02_12_channel_R=10'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t2_c12_r10 in res:
        res = res[t2_c12_r10]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))
# Out:
# Track 02 - 12-channel
# R = 5
# team01,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
# team02,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
# zero-filled-baseline,  0.6338 +/- 0.2082, 21.9547 +/- 6.8183, 0.0702 +/- 0.0302
#
#
#
# R = 10
# team01,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273
# team02,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273
# zero-filled-baseline,  0.5722 +/- 0.2158, 20.8307 +/- 7.0375, 0.0612 +/- 0.0273

# %%
print("Track 02 - 32-channel")
print("R = 5")
t2_c32_r5 = 'track02_32_channel_R=5'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t2_c32_r5 in res:
        res = res[t2_c32_r5]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))

print("\n\n")

print("R = 10")
t2_c32_r10 = 'track02_32_channel_R=10'
for ii in results:
    name = ii.split("/")[-1].split(".pickle")[0]
    
    res_file = open(ii,'rb')
    res = pickle.load(res_file)
    res_file.close()
    
    if t2_c32_r10 in res:
        res = res[t2_c32_r10]
        ssim = res[:,0].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        psnr = res[:,1].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        vif = res[:,2].reshape(nslices,nfiles)[crop[0]:-crop[1],:]
        print("%s,  %.4f +/- %.4f, %.4f +/- %.4f, %.4f +/- %.4f" %(name,ssim.mean(),ssim.std(),psnr.mean(),psnr.std(),\
                                                                  vif.mean(),vif.std()))
# Out:
# Track 02 - 32-channel
# R = 5
# team01,  0.6346 +/- 0.2289, 20.1950 +/- 8.7054, 0.0610 +/- 0.0256
# team02,  0.6346 +/- 0.2289, 20.1950 +/- 8.7054, 0.0610 +/- 0.0256
# zero-filled-baseline,  0.6346 +/- 0.2289, 20.1950 +/- 8.7054, 0.0610 +/- 0.0256
#
#
#
# R = 10
# team01,  0.5750 +/- 0.2445, 19.0049 +/- 9.0003, 0.0525 +/- 0.0230
# team02,  0.5750 +/- 0.2445, 19.0049 +/- 9.0003, 0.0525 +/- 0.0230
# zero-filled-baseline,  0.5750 +/- 0.2445, 19.0049 +/- 9.0003, 0.0525 +/- 0.0230
